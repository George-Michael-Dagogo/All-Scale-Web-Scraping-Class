# %%
pip install pandas fake_useragent

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import concurrent.futures
import pandas as pd

# %%
product_brands = []
product_names = []
current_prices = []
old_prices = []
ratings = []
product_urls = []

def scrape_macy(url):
    ua = UserAgent()
    userAgent = ua.random
    headers = {'User-Agent': userAgent}
    page = requests.get(url, headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    sales_box = soup.find_all('div', class_='product-thumbnail-container')


    for box in sales_box:
        #product_brand
        if box.find('div', class_ = 'product-brand medium') is not None:
            product_brand = box.find('div', class_ = 'product-brand medium').text.lstrip()
            product_brands.append(product_brand)
        else:
            product_brands.append('None')

                #product_name
        if box.find('div', class_ = "product-name medium") is not None:
            product_name = box.find('div', class_ = "product-name medium").text.lstrip() 
            product_names.append(product_name)
        else:
            product_names.append('None')  


            #price
        if box.find('span', class_ = "discount price-reg") is not None:
            current_price = box.find('span', class_ = "discount price-reg").text.strip() 
            current_prices.append(current_price)
        elif box.find('span', class_ = "price-reg") is not None:
            current_price = box.find('span', class_ = "price-reg").text.strip()
            current_prices.append(current_price)
        else:
            current_prices.append('None')  

                #old price 
        if box.find('span', class_ = "price-strike") is not None:
            old_price = box.find('span', class_ = "price-strike").text
            old_prices.append(old_price)
        else:
            old_prices.append('None')

            #rating
        if box.select_one('div.rating > div > fieldset') is not None:
            rating = box.select_one('div.rating > div > fieldset')
            rating = rating['aria-label']
            ratings.append(rating)
        else:
            ratings.append('None')


        if box.find('a', attrs={"href": True}) is not None:
            product_url = box.find('a', attrs={"href": True}) 
            product_url = product_url['href']
            product_urls.append('https://www.macys.com'+product_url)
        else:
            product_urls.append('None')

    if soup.find('a', class_ = 'pagination-next') is None:
        a = 1
        b = 'e'
        a+b
    else:
        pass

index = 1
while True:
    try: 
        url = 'https://www.macys.com/shop/handbags-accessories'
        page = '/Pageindex/'+ '{}?id=26846'.format(index)
        index += 1
        new_url = url+page
        scrape_macy(new_url)
        print(new_url)
        print(len(product_brands))
    except Exception as e:
        print(e)
        break


data = pd.DataFrame({
    'Product Brand': product_brands,
    'Product Name': product_names,
    'Current Price': current_prices,
    'Old Price': old_prices,
    'Rating': ratings,
    'Product URL': product_urls
})
data
# Out:
# https://www.macys.com/shop/handbags-accessories/Pageindex/1?id=26846
# 120
# https://www.macys.com/shop/handbags-accessories/Pageindex/2?id=26846
# 240
# https://www.macys.com/shop/handbags-accessories/Pageindex/3?id=26846
# 360
# https://www.macys.com/shop/handbags-accessories/Pageindex/4?id=26846
# 480
# https://www.macys.com/shop/handbags-accessories/Pageindex/5?id=26846
# 600
# https://www.macys.com/shop/handbags-accessories/Pageindex/6?id=26846
# 720
# https://www.macys.com/shop/handbags-accessories/Pageindex/7?id=26846
# 840
# https://www.macys.com/shop/handbags-accessories/Pageindex/8?id=26846
# 960
# https://www.macys.com/shop/handbags-accessories/Pageindex/9?id=26846
# 1080
# https://www.macys.com/shop/handbags-accessories/Pageindex/10?id=26846
# 1200
# https://www.macys.com/shop/handbags-accessories/Pageindex/11?id=26846
# 1320
# https://www.macys.com/shop/handbags-accessories/Pageindex/12?id=26846
# 1440
# https://www.macys.com/shop/handbags-accessories/Pageindex/13?id=26846
# 1560
# https://www.macys.com/shop/handbags-accessories/Pageindex/14?id=26846
# 1680
# https://www.macys.com/shop/handbags-accessories/Pageindex/15?id=26846
# 1800
# https://www.macys.com/shop/handbags-accessories/Pageindex/16?id=26846
# 1920
# https://www.macys.com/shop/handbags-accessories/Pageindex/17?id=26846
# 2040
# https://www.macys.com/shop/handbags-accessories/Pageindex/18?id=26846
# 2160
# https://www.macys.com/shop/handbags-accessories/Pageindex/19?id=26846
# 2280
# https://www.macys.com/shop/handbags-accessories/Pageindex/20?id=26846
# 2400
# https://www.macys.com/shop/handbags-accessories/Pageindex/21?id=26846
# 2520
# https://www.macys.com/shop/handbags-accessories/Pageindex/22?id=26846
# 2640
# https://www.macys.com/shop/handbags-accessories/Pageindex/23?id=26846
# 2760
# https://www.macys.com/shop/handbags-accessories/Pageindex/24?id=26846
# 2880
# https://www.macys.com/shop/handbags-accessories/Pageindex/25?id=26846
# 3000
# https://www.macys.com/shop/handbags-accessories/Pageindex/26?id=26846
# 3120
# https://www.macys.com/shop/handbags-accessories/Pageindex/27?id=26846
# 3240
# https://www.macys.com/shop/handbags-accessories/Pageindex/28?id=26846
# 3360
# unsupported operand type(s) for +: 'int' and 'str'
#             Product Brand                                       Product Name  \
# 0     kate spade new york  Disney | Macy's Minnie Mouse Medium Market Tot...
# 1     kate spade new york  Disney | Macy's Minnie Mouse Medium Market Tot...
# 2      Stoney Clover Lane  Disney | Macy's Thanksgiving Day Parade Small ...
# 3      Stoney Clover Lane  Disney | Macy's Thanksgiving Day Parade Small ...
# 4            Charter Club     Ribbed 100% Cashmere Scarf, Created for Macy's
# ...                   ...                                                ...
# 3401              Kipling                            Seoul Go Large Backpack
# 3402           Style & Co   Whipstitch Medium Crossbody, Created for Macy's
# 3403           Style & Co   Whipstitch Medium Crossbody, Created for Macy's
# 3404              Brahmin         NEW! Caroline Marana Small Leather Satchel
# 3405              Brahmin         NEW! Caroline Marana Small Leather Satchel
#
#         Current Price     Old Price                               Rating  \
# 0          EUR 290.99          None         Rated 5 stars with 2 reviews
# 1          EUR 290.99          None         Rated 5 stars with 2 reviews
# 2           EUR 95.70          None                                 None
# 3           EUR 95.70          None                                 None
# 4     Sale  EUR 39.05   EUR 105.95   Rated 4.0422 stars with 166 reviews
# ...               ...           ...                                  ...
# 3401   Now  EUR 78.51   EUR 130.85                                  None
# 3402  Sale  EUR 31.05    EUR 77.63                                  None
# 3403  Sale  EUR 31.05    EUR 77.63                                  None
# 3404       EUR 375.95          None                                 None
# 3405       EUR 375.95          None                                 None
#
#                                             Product URL
# 0     https://www.macys.com/shop/product/disney-macy...
# 1     https://www.macys.com/shop/product/disney-macy...
# 2     https://www.macys.com/shop/product/disney-macy...
# 3     https://www.macys.com/shop/product/disney-macy...
# 4     https://www.macys.com/shop/product/charter-clu...
# ...                                                 ...
# 3401  https://www.macys.com/shop/product/kipling-seo...
# 3402  https://www.macys.com/shop/product/style-co-wh...
# 3403  https://www.macys.com/shop/product/style-co-wh...
# 3404  https://www.macys.com/shop/product/brahmin-car...
# 3405  https://www.macys.com/shop/product/brahmin-car...
#
# [3406 rows x 6 columns]

# %%
len(set(product_urls))
# Out:
# 1533
