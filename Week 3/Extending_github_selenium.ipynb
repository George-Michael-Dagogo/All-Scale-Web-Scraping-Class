# %%
from selenium.webdriver import Chrome
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from fake_useragent import UserAgent
#from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
import time
import requests  # For making HTTP requests
from bs4 import BeautifulSoup  # For parsing HTML content
from fake_useragent import UserAgent  # For generating random user agents
import pandas as pd  # For data manipulation and creating DataFrames
import numpy as np
import concurrent.futures
from selenium.common.exceptions import NoSuchElementException

service = Service(executable_path=r'C:\Users\H i - G E O R G E\Documents\All_scale\chromedriver.exe')
driver = webdriver.Chrome(service=service)

driver.get("https://github.com/trending")
driver.implicitly_wait(20)

try:
    time_dropdown = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//details[@id='select-menu-date']")))
    time_dropdown.click()

    this_month_option = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//span[contains(text(), 'This month')]")))
    this_month_option.click()

    time.sleep(5)
    
    language_dropdown = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//details[@id='select-menu-language']")))
    language_dropdown.click()

    python_option = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//span[contains(text(), 'Python')]")))
    python_option.click()

except Exception as e:
    print(e)

time.sleep(5)
repos = driver.find_elements(By.XPATH, "//h2[@class='h3 lh-condensed']")

descriptions = driver.find_elements(By.CLASS_NAME, "col-9.color-fg-muted.my-1.pr-4")

stars = driver.find_elements(By.XPATH, ".//a[contains(@href, '/stargazers')]")

forks = driver.find_elements(By.XPATH, ".//a[contains(@href, '/forks')]")

repo_names = [repo.text.strip() for repo in repos]
repo_descriptions = [desc.text.strip() for desc in descriptions]
repo_stars = [star.text.strip() for star in stars]
repo_forks = [fork.text.strip() for fork in forks]


df = pd.DataFrame({
    'Repository': repo_names,
    'Descriptions': repo_descriptions,
    'Number of Stars': repo_stars,
    'Number of Forks':repo_forks
})
driver.quit()
df
# Out:
#                           Repository  \
# 0              stanford-oval / storm
# 1    DrewThomasson / ebook2audiobook
# 2                OpenBMB / MiniCPM-o
# 3               unclecode / crawl4ai
# 4                     khoj-ai / khoj
# 5             jingyaogong / minimind
# 6               bytedance / monolith
# 7                      OpenSPG / KAG
# 8           microsoft / PromptWizard
# 9                fixie-ai / ultravox
# 10          All-Hands-AI / OpenHands
# 11  nautechsystems / nautilus_trader
# 12     harry0703 / MoneyPrinterTurbo
# 13              sgl-project / sglang
# 14                crewAIInc / crewAI
# 15   Shubhamsaboo / awesome-llm-apps
# 16               serengil / deepface
#
#                                          Descriptions Number of Stars  \
# 0   An LLM-powered knowledge curation system that ...          20,934
# 1   Convert ebooks to audiobooks with chapters and...           7,620
# 2   MiniCPM-o 2.6: A GPT-4o Level MLLM for Vision,...          17,732
# 3   🚀🤖 Crawl4AI: Open-source LLM Friendly Web Craw...          27,197
# 4   Your AI second brain. Self-hostable. Get answe...          25,284
# 5   🚀🚀 「大模型」3小时完全从0训练26M的小参数GPT！🌏 Train a 26M-para...           6,793
# 6                 A Lightweight Recommendation System           8,333
# 7   KAG is a logical form-guided reasoning and ret...           4,687
# 8   Task-Aware Agent-driven Prompt Optimization Fr...           2,359
# 9           A fast multimodal LLM for real-time voice           3,182
# 10                  🙌 OpenHands: Code Less, Make More          44,515
# 11  A high-performance algorithmic trading platfor...           4,060
# 12  利用AI大模型，一键生成高清短视频 Generate short videos with o...          21,186
# 13  SGLang is a fast serving framework for large l...           7,727
# 14  Framework for orchestrating role-playing, auto...          25,382
# 15  Collection of awesome LLM apps with AI Agents ...          13,410
# 16  A Lightweight Face Recognition and Facial Attr...          17,280
#
#    Number of Forks
# 0            1,843
# 1              527
# 2            1,275
# 3            2,131
# 4            1,361
# 5              719
# 6              634
# 7              293
# 8              198
# 9              202
# 10           4,919
# 11             647
# 12           3,188
# 13             749
# 14           3,432
# 15           1,444
# 16           2,400

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from fake_useragent import UserAgent
#from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
import time
import requests  # For making HTTP requests
from bs4 import BeautifulSoup  # For parsing HTML content
from fake_useragent import UserAgent  # For generating random user agents
import pandas as pd  # For data manipulation and creating DataFrames
import numpy as np
import concurrent.futures
from selenium.common.exceptions import NoSuchElementException

service = Service(executable_path=r'C:\Users\H i - G E O R G E\Documents\All_scale\chromedriver.exe')
driver = webdriver.Chrome(service=service)
driver.get("https://github.com/trending")


repo_boxes = driver.find_elements(By.XPATH, "//article[@class='Box-row']")


repositories = []
descriptions = []
stars = []
forks = []
languages = []

for box in repo_boxes:
    # Repository Title
    repo_title_elements = box.find_elements(By.XPATH, ".//h2[@class='h3 lh-condensed']")
    if repo_title_elements:
        repositories.append(repo_title_elements[0].text.strip())
    else:
        repositories.append('None')
    
    # Description
    desc_elements = box.find_elements(By.CLASS_NAME, "col-9.color-fg-muted.my-1.pr-4")
    if desc_elements:
        descriptions.append(desc_elements[0].text.strip())
    else:
        descriptions.append('None')
    
    # Stars
    star_elements = box.find_elements(By.XPATH, ".//a[contains(@href, '/stargazers')]")
    if star_elements:
        stars.append(star_elements[0].text.strip())
    else:
        stars.append('None')
    
    # Forks
    fork_elements = box.find_elements(By.XPATH, ".//a[contains(@href, '/forks')]")
    if fork_elements:
        forks.append(fork_elements[0].text.strip())
    else:
        forks.append('None')
    
    # Language
    language_elements = box.find_elements(By.XPATH, ".//span[@itemprop='programmingLanguage']")
    if language_elements:
        languages.append(language_elements[0].text.strip())
    else:
        languages.append('None')


df = pd.DataFrame({
    'Repository': repositories,
    'Description': descriptions,
    'Stars': stars,
    'Forks': forks,
    'Language': languages
})


driver.quit()
df.to_csv('bs4_Code_approach.csv')
df
# Out:
#                                     Repository  \
# 0   deepseek-ai / awesome-deepseek-integration
# 1                        CorentinTh / it-tools
# 2               AmruthPillai / Reactive-Resume
# 3                      browserbase / stagehand
# 4                      lightpanda-io / browser
# 5                                php / php-src
# 6                        nextjs / saas-starter
# 7       DataExpert-io / data-engineer-handbook
# 8                      yassinebenaid / bunster
# 9                        shadps4-emu / shadPS4
# 10                     storybookjs / storybook
#
#                                           Description   Stars  Forks  \
# 0                                                None   2,563    246
# 1   Collection of handy online tools for developer...  25,383  3,091
# 2   A one-of-a-kind resume builder that keeps your...  28,394  2,878
# 3   An AI web browsing framework focused on simpli...   6,484    287
# 4   Lightpanda: the headless browser designed for ...   3,257     66
# 5                                 The PHP Interpreter  38,564  7,802
# 6   Get started quickly with Next.js, Postgres, St...   9,345    963
# 7   This is a repo with links to everything you'd ...  25,625  5,001
# 8           Compile shell scripts to static binaries.     963     20
# 9   PlayStation 4 emulator for Windows, Linux and ...  16,417  1,005
# 10  Storybook is the industry standard workshop fo...  85,444  9,402
#
#             Language
# 0               None
# 1                Vue
# 2         TypeScript
# 3         TypeScript
# 4                Zig
# 5                  C
# 6         TypeScript
# 7   Jupyter Notebook
# 8                 Go
# 9                C++
# 10        TypeScript
